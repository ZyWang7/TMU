# %% [markdown]
# ## Load the model

# %%
import os
import os.path as osp
import argparse
import numpy as np
import torchvision.transforms as transforms
import torch.backends.cudnn as cudnn
import torch
import cv2
import datetime
from tqdm import tqdm
from pathlib import Path
from human_models.human_models import SMPLX
from ultralytics import YOLO
from main.base import Tester
from main.config import Config
from utils.data_utils import load_img, process_bbox, generate_patch_image
from utils.visualization_utils import render_mesh
from utils.inference_utils import non_max_suppression

# %%
cudnn.benchmark = True

ckpt_name = "smplest_x_h"
file_name = "01.mp4"

# init config
time_str = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
root_dir = ""
config_path = osp.join('./pretrained_models', ckpt_name, 'config_base.py')
cfg = Config.load_config(config_path)
checkpoint_path = osp.join('./pretrained_models', ckpt_name, f'{ckpt_name}.pth.tar')
img_folder = osp.join(root_dir, 'demo', 'input_frames', file_name)
output_folder = osp.join(root_dir, 'demo', 'output_frames', file_name)
os.makedirs(output_folder, exist_ok=True)
exp_name = f'inference_{file_name}_{ckpt_name}_{time_str}'

new_config = {
    "model": {
        "pretrained_model_path": checkpoint_path,
    },
    "log":{
        'exp_name':  exp_name,
        'log_dir': osp.join(root_dir, 'outputs', exp_name, 'log'),  
        }
}
cfg.update_config(new_config)

# init human models
smpl_x = SMPLX(cfg.model.human_model_path)

# init tester
demoer = Tester(cfg)
demoer._make_model()
# Out:
# 08-11 14:38:39 Load checkpoint from ./pretrained_models\smplest_x_h\smplest_x_h.pth.tar
# 08-11 14:38:39 Creating graph...
# Total #parameters: 687223152 (0.69B)
# 08-11 14:38:45 WRN: Attention: Strict=False is set for checkpoint loading. Please check manually.

# %%
demoer.model
# Out:
# DataParallel(
#   (module): Model(
#     (encoder): ViT(
#       (patch_embed): PatchEmbed(
#         (proj): Conv2d(3, 1280, kernel_size=(16, 16), stride=(16, 16), padding=(2, 2))
#       )
#       (blocks): ModuleList(
#         (0): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.017741935327649117)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.03548387065529823)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.0532258078455925)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.07096774131059647)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.08870967477560043)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.106451615691185)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.12419354915618896)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.14193548262119293)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (9): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.1596774160861969)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (10): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.17741934955120087)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (11): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.19516128301620483)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (12): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.21290323138237)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.23064516484737396)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.24838709831237793)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (15): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.2661290168762207)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (16): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.28387099504470825)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (17): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.301612913608551)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (18): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.3193548321723938)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (19): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.33709678053855896)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (20): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.3548387289047241)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (21): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.3725806474685669)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (22): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.39032259583473206)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (23): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.4080645442008972)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (24): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.42580646276474)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (25): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.44354838132858276)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (26): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.4612903296947479)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (27): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.4790322780609131)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (28): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.49677419662475586)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (29): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.5145161151885986)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (30): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.5322580933570862)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (31): Block(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention_ViT(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.550000011920929)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (last_norm): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#     )
#     (decoder): TransformerDecoderHead(
#       (transformer): TransformerDecoder(
#         (to_token_embedding): Linear(in_features=80, out_features=1280, bias=True)
#         (dropout): DropTokenDropout()
#         (transformer): TransformerCrossAttn(
#           (layers): ModuleList(
#             (0-5): 6 x ModuleList(
#               (0): PreNorm(
#                 (norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#                 (fn): Attention(
#                   (to_qkv): Linear(in_features=1280, out_features=1536, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=512, out_features=1280, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#               )
#               (1): PreNorm(
#                 (norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#                 (fn): CrossAttention(
#                   (to_kv): Linear(in_features=1280, out_features=1024, bias=False)
#                   (to_q): Linear(in_features=1280, out_features=512, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=512, out_features=1280, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#               )
#               (2): PreNorm(
#                 (norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#                 (fn): FeedForward(
#                   (net): Sequential(
#                     (0): Linear(in_features=1280, out_features=1280, bias=True)
#                     (1): GELU(approximate='none')
#                     (2): Dropout(p=0.0, inplace=False)
#                     (3): Linear(in_features=1280, out_features=1280, bias=True)
#                     (4): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (token_conv): Linear(in_features=1280, out_features=512, bias=True)
#       (dec_body_root_pose): Linear(in_features=512, out_features=6, bias=True)
#       (dec_body_pose): Linear(in_features=10752, out_features=126, bias=True)
#       (dec_body_shape): Linear(in_features=5120, out_features=10, bias=True)
#       (dec_body_cam): Linear(in_features=512, out_features=3, bias=True)
#       (dec_hand_root_pose): Linear(in_features=1024, out_features=12, bias=True)
#       (dec_hand_pose): Linear(in_features=15360, out_features=180, bias=True)
#       (dec_hand_cam): Linear(in_features=1024, out_features=6, bias=True)
#       (dec_face_root_pose): Linear(in_features=512, out_features=6, bias=True)
#       (dec_face_expression): Linear(in_features=5120, out_features=10, bias=True)
#       (dec_face_jaw_pose): Linear(in_features=512, out_features=6, bias=True)
#       (dec_face_cam): Linear(in_features=512, out_features=3, bias=True)
#     )
#     (smplx_layer): SMPLX(
#       Gender: NEUTRAL
#       Number of joints: 55
#       Betas: 10
#       Flat hand mean: False
#       Number of Expression Coefficients: 10
#       (vertex_joint_selector): VertexJointSelector()
#     )
#     (coord_loss): CoordLoss()
#     (param_loss): ParamLoss()
#   )
# )

# %%
bbox_model = getattr(cfg.inference.detection, "model_path", 
                        './pretrained_models/yolov8x.pt')
detector = YOLO(bbox_model)

# %% [markdown]
# ## Convert the Video into Frames

# %%
import subprocess
import shutil
import sys

FPS = 15
DEMO_DIR = Path("demo")
IMG_PATH = Path("demo/input_frames/01.mp4")
FILE_NAME = "01.mp4"

# Setup paths and ensure the output directory exists
input_file = DEMO_DIR / FILE_NAME
IMG_PATH.mkdir(parents=True, exist_ok=True)
# Check if the input file actually exists
if not input_file.is_file():
    print(f"Error: Input file not found at '{input_file}'")
    sys.exit(1)

ext = input_file.suffix[1:].lower()
video_extensions = {'mp4', 'avi', 'mov', 'mkv', 'flv', 'wmv', 'webm', 'mpeg', 'mpg'}
image_extensions = {'jpg', 'jpeg', 'png', 'bmp', 'gif', 'tiff', 'tif', 'webp', 'svg'}

try:
    if ext in video_extensions:
        print(f"Processing video: {FILE_NAME}")
        # This command is the Python equivalent of the ffmpeg shell command
        command = [
            'ffmpeg',
            '-i', str(input_file),
            '-f', 'image2',
            '-vf', f'fps={FPS}/1',
            '-qscale:v', '2',  # Good quality, 0 is lossless but creates huge files
            str(IMG_PATH / '%06d.jpg')
        ]
        subprocess.run(command, check=True, capture_output=True, text=True)
    elif ext in image_extensions:
        print(f"Processing image: {FILE_NAME}")
        # Copy the image to the destination, renaming it in the process
        dest_file = IMG_PATH / f"000001.{ext}"
        shutil.copy(str(input_file), str(dest_file))
    else:
        print(f"Unknown file type: '{ext}'")
        sys.exit(1)
except subprocess.CalledProcessError as e:
    # This will catch errors from ffmpeg (e.g., corrupted file)
    print("An error occurred during ffmpeg processing:")
    print(f"Stderr: {e.stderr}")
    sys.exit(1)
except Exception as e:
    # Catch other potential errors
    print(f"An unexpected error occurred: {e}")
    sys.exit(1)

# Count the resulting files
end_count = len(os.listdir(IMG_PATH))
print(f"\nSuccess! Total files in output directory: {end_count}")

# %% [markdown]
# ## Process example images

# %%
num_example = 10
for frame in tqdm(range(1, num_example+1)):    
    # prepare input image
    img_path =osp.join("demo/input_frames/01.mp4", f'{int(frame):06d}.jpg')

    transform = transforms.ToTensor()
    original_img = load_img(img_path)
    vis_img = original_img.copy()
    original_img_height, original_img_width = original_img.shape[:2]
    
    # detection, xyxy
    yolo_bbox = detector.predict(original_img, 
                            device='cuda', 
                            classes=00, 
                            conf=cfg.inference.detection.conf, 
                            save=cfg.inference.detection.save, 
                            verbose=cfg.inference.detection.verbose
                                )[0].boxes.xyxy.detach().cpu().numpy()

    num_bbox = 1
    # loop all detected bboxes
    for bbox_id in range(num_bbox):
        yolo_bbox_xywh = np.zeros((4))
        yolo_bbox_xywh[0] = yolo_bbox[bbox_id][0]
        yolo_bbox_xywh[1] = yolo_bbox[bbox_id][1]
        yolo_bbox_xywh[2] = abs(yolo_bbox[bbox_id][2] - yolo_bbox[bbox_id][0])
        yolo_bbox_xywh[3] = abs(yolo_bbox[bbox_id][3] - yolo_bbox[bbox_id][1])
        # xywh
        bbox = process_bbox(bbox=yolo_bbox_xywh, 
                            img_width=original_img_width, 
                            img_height=original_img_height, 
                            input_img_shape=cfg.model.input_img_shape, 
                            ratio=getattr(cfg.data, "bbox_ratio", 1.25))                
        img, _, _ = generate_patch_image(cvimg=original_img, 
                                            bbox=bbox, 
                                            scale=1.0, 
                                            rot=0.0, 
                                            do_flip=False, 
                                            out_shape=cfg.model.input_img_shape)
        img = transform(img.astype(np.float32))/255
        img = img[None,:,:,:]
        inputs = {'img': img}
        targets = {}
        meta_info = {}

        # mesh recovery
        with torch.no_grad():
            out = demoer.model(inputs, targets, meta_info, 'test')
        mesh = out['smplx_mesh_cam'].detach().cpu().numpy()[0]
        # render mesh
        focal = [cfg.model.focal[0] / cfg.model.input_body_shape[1] * bbox[2], 
                    cfg.model.focal[1] / cfg.model.input_body_shape[0] * bbox[3]]
        princpt = [cfg.model.princpt[0] / cfg.model.input_body_shape[1] * bbox[2] + bbox[0], 
                    cfg.model.princpt[1] / cfg.model.input_body_shape[0] * bbox[3] + bbox[1]]
        # draw the bbox on img
        vis_img = cv2.rectangle(vis_img, (int(yolo_bbox[bbox_id][0]), int(yolo_bbox[bbox_id][1])), 
                                (int(yolo_bbox[bbox_id][2]), int(yolo_bbox[bbox_id][3])), (0, 255, 0), 1)
        # draw mesh
        vis_img = render_mesh(vis_img, mesh, smpl_x.face, {'focal': focal, 'princpt': princpt}, mesh_as_vertices=False)
    # save rendered image
    frame_name = os.path.basename(img_path)
    cv2.imwrite(os.path.join(output_folder, frame_name), vis_img[:, :, ::-1])

# %% [markdown]
# ## Apply Unmerge_ToMe

# %%
import tmu

tmu.patch.timm(demoer.model.module.encoder, trace_source=True)
demoer.model
# Out:
# DataParallel(
#   (module): Model(
#     (encoder): ToMeVisionTransformer(
#       (patch_embed): PatchEmbed(
#         (proj): Conv2d(3, 1280, kernel_size=(16, 16), stride=(16, 16), padding=(2, 2))
#       )
#       (blocks): ModuleList(
#         (0): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.017741935327649117)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.03548387065529823)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.0532258078455925)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.07096774131059647)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.08870967477560043)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.106451615691185)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.12419354915618896)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.14193548262119293)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (9): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.1596774160861969)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (10): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.17741934955120087)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (11): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.19516128301620483)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (12): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.21290323138237)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.23064516484737396)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.24838709831237793)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (15): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.2661290168762207)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (16): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.28387099504470825)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (17): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.301612913608551)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (18): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.3193548321723938)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (19): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.33709678053855896)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (20): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.3548387289047241)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (21): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.3725806474685669)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (22): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.39032259583473206)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (23): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.4080645442008972)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (24): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.42580646276474)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (25): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.44354838132858276)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (26): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.4612903296947479)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (27): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.4790322780609131)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (28): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.49677419662475586)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (29): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.5145161151885986)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (30): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.5322580933570862)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (31): ToMeBlock(
#           (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (attn): ToMeAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(p=0.550000011920929)
#           (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (last_norm): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#     )
#     (decoder): TransformerDecoderHead(
#       (transformer): TransformerDecoder(
#         (to_token_embedding): Linear(in_features=80, out_features=1280, bias=True)
#         (dropout): DropTokenDropout()
#         (transformer): TransformerCrossAttn(
#           (layers): ModuleList(
#             (0-5): 6 x ModuleList(
#               (0): PreNorm(
#                 (norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#                 (fn): Attention(
#                   (to_qkv): Linear(in_features=1280, out_features=1536, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=512, out_features=1280, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#               )
#               (1): PreNorm(
#                 (norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#                 (fn): CrossAttention(
#                   (to_kv): Linear(in_features=1280, out_features=1024, bias=False)
#                   (to_q): Linear(in_features=1280, out_features=512, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=512, out_features=1280, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#               )
#               (2): PreNorm(
#                 (norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#                 (fn): FeedForward(
#                   (net): Sequential(
#                     (0): Linear(in_features=1280, out_features=1280, bias=True)
#                     (1): GELU(approximate='none')
#                     (2): Dropout(p=0.0, inplace=False)
#                     (3): Linear(in_features=1280, out_features=1280, bias=True)
#                     (4): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (token_conv): Linear(in_features=1280, out_features=512, bias=True)
#       (dec_body_root_pose): Linear(in_features=512, out_features=6, bias=True)
#       (dec_body_pose): Linear(in_features=10752, out_features=126, bias=True)
#       (dec_body_shape): Linear(in_features=5120, out_features=10, bias=True)
#       (dec_body_cam): Linear(in_features=512, out_features=3, bias=True)
#       (dec_hand_root_pose): Linear(in_features=1024, out_features=12, bias=True)
#       (dec_hand_pose): Linear(in_features=15360, out_features=180, bias=True)
#       (dec_hand_cam): Linear(in_features=1024, out_features=6, bias=True)
#       (dec_face_root_pose): Linear(in_features=512, out_features=6, bias=True)
#       (dec_face_expression): Linear(in_features=5120, out_features=10, bias=True)
#       (dec_face_jaw_pose): Linear(in_features=512, out_features=6, bias=True)
#       (dec_face_cam): Linear(in_features=512, out_features=3, bias=True)
#     )
#     (smplx_layer): SMPLX(
#       Gender: NEUTRAL
#       Number of joints: 55
#       Betas: 10
#       Flat hand mean: False
#       Number of Expression Coefficients: 10
#       (vertex_joint_selector): VertexJointSelector()
#     )
#     (coord_loss): CoordLoss()
#     (param_loss): ParamLoss()
#   )
# )

# %%
demoer.model.module.encoder.r = 2
out_folder = "demo/output_frames/tmu_r" + str(demoer.model.module.encoder.r)
os.makedirs(out_folder, exist_ok=True)

num_example = 10
for frame in tqdm(range(1, num_example+1)):    
    # prepare input image
    img_path =osp.join("demo/input_frames/01.mp4", f'{int(frame):06d}.jpg')

    transform = transforms.ToTensor()
    original_img = load_img(img_path)
    vis_img = original_img.copy()
    original_img_height, original_img_width = original_img.shape[:2]
    
    # detection, xyxy
    yolo_bbox = detector.predict(original_img, 
                            device='cuda', 
                            classes=00, 
                            conf=cfg.inference.detection.conf, 
                            save=cfg.inference.detection.save, 
                            verbose=cfg.inference.detection.verbose
                                )[0].boxes.xyxy.detach().cpu().numpy()

    num_bbox = 1
    # loop all detected bboxes
    for bbox_id in range(num_bbox):
        yolo_bbox_xywh = np.zeros((4))
        yolo_bbox_xywh[0] = yolo_bbox[bbox_id][0]
        yolo_bbox_xywh[1] = yolo_bbox[bbox_id][1]
        yolo_bbox_xywh[2] = abs(yolo_bbox[bbox_id][2] - yolo_bbox[bbox_id][0])
        yolo_bbox_xywh[3] = abs(yolo_bbox[bbox_id][3] - yolo_bbox[bbox_id][1])
        # xywh
        bbox = process_bbox(bbox=yolo_bbox_xywh, 
                            img_width=original_img_width, 
                            img_height=original_img_height, 
                            input_img_shape=cfg.model.input_img_shape, 
                            ratio=getattr(cfg.data, "bbox_ratio", 1.25))                
        img, _, _ = generate_patch_image(cvimg=original_img, 
                                            bbox=bbox, 
                                            scale=1.0, 
                                            rot=0.0, 
                                            do_flip=False, 
                                            out_shape=cfg.model.input_img_shape)
        img = transform(img.astype(np.float32))/255
        img = img[None,:,:,:]
        inputs = {'img': img}
        targets = {}
        meta_info = {}
        with torch.no_grad():
            out = demoer.model(inputs, targets, meta_info, 'test')
        mesh = out['smplx_mesh_cam'].detach().cpu().numpy()[0]
        # render mesh
        focal = [cfg.model.focal[0] / cfg.model.input_body_shape[1] * bbox[2], 
                    cfg.model.focal[1] / cfg.model.input_body_shape[0] * bbox[3]]
        princpt = [cfg.model.princpt[0] / cfg.model.input_body_shape[1] * bbox[2] + bbox[0], 
                    cfg.model.princpt[1] / cfg.model.input_body_shape[0] * bbox[3] + bbox[1]]
        # draw the bbox on img
        vis_img = cv2.rectangle(vis_img, (int(yolo_bbox[bbox_id][0]), int(yolo_bbox[bbox_id][1])), 
                                (int(yolo_bbox[bbox_id][2]), int(yolo_bbox[bbox_id][3])), (0, 255, 0), 1)
        # draw mesh
        vis_img = render_mesh(vis_img, mesh, smpl_x.face, {'focal': focal, 'princpt': princpt}, mesh_as_vertices=False)

    # save rendered image
    frame_name = os.path.basename(img_path)
    cv2.imwrite(os.path.join(out_folder, frame_name), vis_img[:, :, ::-1])
